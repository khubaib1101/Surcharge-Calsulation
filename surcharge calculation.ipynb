# %%
# Surcharge calculation
total_bill = 21000
surcharge = 0.10
final_bill = 0
if total_bill >=20000:
  surcharge = total_bill * 0.10
  final_bill = total_bill + surcharge
  print("You have exceeded the 20,000 limit therefore your surcharge is =",final_bill)
else:
  print("You are within the limits therefore no surcharge")
